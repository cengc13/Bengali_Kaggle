# %%
from tensorflow import keras

# %%
model_path = "./saved_models/dense121_128x128_1.h5"
model = keras.models.load_model(model_path)

# %%
config = model.get_config()
config
# Out:
# {'name': 'model',
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 128, 128, 1),
#     'dtype': 'float32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'input_2'},
#    'name': 'input_2',
#    'inbound_nodes': []},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 3,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotNormal',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': {'class_name': 'L1L2',
#      'config': {'l1': 9.999999747378752e-05, 'l2': 0.0}},
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-9bf5b33a4ffd> in <module>
# ----> 1 model_new = keras.models.model_from_config(config)
#       2 model_new.summary()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/saving/model_config.py in model_from_config(config, custom_objects)
#      53                     '`Sequential.from_config(config)`?')
#      54   from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 55   return deserialize(config, custom_objects=custom_objects)
#      56
#      57
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/layers/serialization.py in deserialize(config, custom_objects)
#      96   globs['SequenceFeatures'] = sfc.SequenceFeatures
#      97
# ---> 98   layer_class_name = config['class_name']
# ...
